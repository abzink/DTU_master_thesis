# %%
import sys
sys.path.append('../')
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/Users/annabzinkowska/DTU/master_thesis/data/processed_data_all_bertopic_vol_1.csv')
# Out:
# /var/folders/n9/qhmmsj1s7w52648j4cjf7ztc0000gn/T/ipykernel_12262/3472323111.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/Users/annabzinkowska/DTU/master_thesis/data/processed_data_all_bertopic_vol_1.csv')

# %%
len(data.columns)
# Out:
# 17

# %%
categorical_columns = ['month_mode', 'quarter_mode','year_mode','day_week_mode', 'customer_country_mode']
numerical_columns = ['quantity_sum', 'price_sum', 'unit_weight', 'unit_price_mean', 'customer_country_count', 'customer_id_count'] 
text_column = 'description'

# %%
from self_training_tuning import SelfTrainingPipeline

pipeline_instance = SelfTrainingPipeline()
pipeline_instance.set_data(data, categorical_columns, numerical_columns, include_text=False)
results = pipeline_instance.run()
# Out:
# /Users/annabzinkowska/anaconda3/envs/thesis_/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Training Classifiers:   0%|          | 0/6 [00:00<?, ?it/s]/Users/annabzinkowska/anaconda3/envs/thesis_/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
